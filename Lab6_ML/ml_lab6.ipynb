# %% [markdown]
# read--split--divide--train--predict--evaluate

# %%
import numpy as np
import pandas as pd

# Define the dataset
data = {
    "area": [100, 150, 200, 250, 300],
    "bedrooms": [2, 3, 3, 4, 5],
    "age": [20, 15, 10, 5, 2],
    "price": [200, 300, 400, 500, 650]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to CSV
df.to_csv("housing.csv", index=False)

print("DataFrame created and saved to housing.csv successfully.")
# Out:
# DataFrame created and saved to housing.csv successfully.

# %% [markdown]
# steap1 read

# %%
df=pd.read_csv("housing.csv")
df.head()
# Out:
#    area  bedrooms  age  price
# 0   100         2   20    200
# 1   150         3   15    300
# 2   200         3   10    400
# 3   250         4    5    500
# 4   300         5    2    650

# %% [markdown]
# step2

# %%
x=df[["area","bedrooms","age"]]
y=df[["price"]]

# %% [markdown]
# step3 splite the data

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %% [markdown]
# step 4 train model
#
# 4.1 create model
#
# 4.2 fit model

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# step5 predict

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# step6 evalute

# %%
import numpy as np # Ensure numpy is imported
from sklearn.metrics import mean_squared_error, r2_score # Import necessary metrics

# Calculate RMSE (Root Mean Squared Error)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("rmse:", rmse)

# Calculate R2 score
r2 = r2_score(y_test, y_pred)
print("R2:", r2)
# Out:
# rmse: 0.0
# R2: nan
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# Ml pipline for liner

# %%
import numpy as np
import pandas as pd # Corrected alias from 'np' to 'pd'

# Define the dataset for student performance prediction
data = {
    "hours_studied": [2, 3, 4, 5, 6, 7, 8, 9],
    "attendence": [50, 60, 70, 80, 85, 90, 95, 100],
    "passed": [0, 0, 0, 1, 1, 1, 1, 1],
    # 'price' column removed as it's not relevant for this classification task
}

df = pd.DataFrame(data)
df.to_csv("student.csv", index=False)

print("DataFrame created and saved to student.csv successfully.")
# Out:
# DataFrame created and saved to student.csv successfully.

# %%
import pandas as pd # Ensure pandas is imported if this cell is run independently
# Read the student data from the previously created CSV file
df = pd.read_csv("student.csv")

# %%
x=df[["hours_studied","attendence"]]
y=df[["passed"]]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression() # Instantiate the LogisticRegression model

# %%
# Fit the Logistic Regression model to the training data
# Flatten y_train to a 1D array as expected by LogisticRegression
model.fit(x_train, y_train.values.ravel())
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Convert y_test to 1D array to match prediction format
y_test_flat = y_test.squeeze()

accuracy = accuracy_score(y_test_flat, y_pred)
precision = precision_score(y_test_flat, y_pred)
recall = recall_score(y_test_flat, y_pred)
f1 = f1_score(y_test_flat, y_pred)

print("accuracy:", accuracy)
print("precision:", precision)
print("recall:", recall)
print("f1_score:", f1)
# Out:
# accuracy: 1.0
# precision: 1.0
# recall: 1.0
# f1_score: 1.0
